# %% [markdown]
# #### Optimized impact on NK estimation

# %%
Base_dir = 'C:/github/LiverDeconv' # cloning repository

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append(Base_dir)
from Optimization import ctrl_norm_comb2ref_optim as cnco

# %% [markdown]
# ***
# ##### Total combination for estimating neutrophil population
# - Distribution of Pearson Correlation for 4095 combinations

# %%
#%% load data
nk_res = pd.read_csv(Base_dir+'/_Figures_new/Figure_4/data/nk_fluctuate_quartile_comb2ref.csv',index_col=0)
nk_res = nk_res.sort_values('NK',ascending=False)

plt.hist(nk_res['NK'],bins=200,zorder=1)
plt.xlabel('Pearson Correlation')
plt.ylabel('Frequency')
plt.rcParams['axes.axisbelow'] = True
plt.grid(color="#ababab",linewidth=0.5)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
plt.title("NK")
plt.show()

# %%
for target in ['LSEC', 'Basophil', 'CD4', 'Neutrophil', 'CD8', 'Eosinophil', 'B', 
               'Kupffer', 'Hepatocyte', 'Cholangiocyte', 'Stellate', 'Monocyte']:
    sns.distplot(
        nk_res['NK'], bins=200, label='all combinations',color='slateblue',kde_kws={"lw": 2},hist_kws={"alpha": 0.6})
    df = nk_res[nk_res['pair'].str.contains("'"+target+"'")]
    
    sns.distplot(
        df['NK'], bins=100, color='forestgreen', label="contains "+target, kde_kws={"lw": 2},hist_kws={"alpha": 0.6}
    )
    
    plt.xlabel('Pearson Correlation')
    plt.ylabel('Frequency')
    plt.rcParams['axes.axisbelow'] = True
    plt.grid(color="#ababab",linewidth=0.5,zorder=-1)
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().yaxis.set_ticks_position('left')
    plt.gca().xaxis.set_ticks_position('bottom')
    plt.title("Combination contains "+target)
    plt.legend()
    plt.show()

# %% [markdown]
# ***
# ##### Summary of good combinations

# %%
#%% Good
# top 10 good combinations
nk_res = pd.read_pickle(Base_dir+'/_Figures_new/Figure_4/data/nk_fluctuate_quartile_comb2ref.pkl')
nk_res = nk_res.sort_values('NK',ascending=False)
print(nk_res.head())
good_combination = nk_res['pair'].tolist()[0:10]

# load data
mix_df = pd.read_csv(Base_dir + '/data/mix_processed.csv',index_col=0)
raw_ref = pd.read_csv(Base_dir + '/data/ref_13types.csv',index_col=0)
val_df = pd.read_csv(Base_dir + '/data/facs_true_population.csv',index_col=0)

# each result of good combinations
ensemble = []
for g in good_combination:
    optim = cnco.Ctrlnorm_comb2ref()
    optim.set_datasets(mix_df=mix_df,val_df=val_df,ignore_samples=['CIV_1','CIV_4','CIV_7','CIV_8','CIP_1','CIP_2','CIP_7','CIP_8'])
    optim.set_target(target="NK")
    optim.select_samples(method="outerquartile",ctrl="Ctrl",threshold=1.5,q=[0, 0.25, 0.5, 0.75, 1],ignore_ctrl=True)
    optim.optimized_single(raw_ref=raw_ref,combination=g,target=["NK"],dec_names=[["NK"]],val_names=[["NK"]],do_plot=True,dpi=100)
    res = optim.final_dec
    val = optim.final_val
    ensemble.append(res["NK"].tolist())

# ensemble the estimated values for each iterations
ensemble_df = pd.DataFrame(ensemble).T
ensemble_df.index = res.index.tolist()
x = optim.final_val["NK"].tolist()
pd.Series(ensemble[0]).corr(pd.Series(x))
x_df = pd.DataFrame(x)
x_df.index = res.index.tolist()
# Out:
#                                                         NK  \
# (Basophil, CD8, Cholangiocyte, Hepatocyte, LSEC...  0.8822
# (Basophil, CD8, Cholangiocyte, Hepatocyte, Mono...  0.8758
# (B, CD8, Cholangiocyte, Eosinophil, Hepatocyte,...  0.8720
# (Basophil, CD8, Cholangiocyte, Eosinophil, Hepa...  0.8687
# (B, Basophil, CD8, Eosinophil, Kupffer, LSEC, N...  0.8667
#
#                                                                                                  pair
# (Basophil, CD8, Cholangiocyte, Hepatocyte, LSEC...  (Basophil, CD8, Cholangiocyte, Hepatocyte, LSE...
# (Basophil, CD8, Cholangiocyte, Hepatocyte, Mono...  (Basophil, CD8, Cholangiocyte, Hepatocyte, Mon...
# (B, CD8, Cholangiocyte, Eosinophil, Hepatocyte,...  (B, CD8, Cholangiocyte, Eosinophil, Hepatocyte...
# (Basophil, CD8, Cholangiocyte, Eosinophil, Hepa...  (Basophil, CD8, Cholangiocyte, Eosinophil, Hep...
# (B, Basophil, CD8, Eosinophil, Kupffer, LSEC, N...  (B, Basophil, CD8, Eosinophil, Kupffer, LSEC, ...
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 70)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 450
# 0 rows are removed
# 0 rows are removed
# number of used genes = 450
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 60)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 400
# 0 rows are removed
# 0 rows are removed
# number of used genes = 400
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 69)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 400
# 0 rows are removed
# 0 rows are removed
# number of used genes = 400
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 89)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 524
# 0 rows are removed
# 0 rows are removed
# number of used genes = 524
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 81)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 450
# 0 rows are removed
# 0 rows are removed
# number of used genes = 450
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 72)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 450
# 0 rows are removed
# 0 rows are removed
# number of used genes = 450
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 74)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 450
# 0 rows are removed
# 0 rows are removed
# number of used genes = 450
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 82)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 500
# 0 rows are removed
# 0 rows are removed
# number of used genes = 500
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 86)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 500
# 0 rows are removed
# 0 rows are removed
# number of used genes = 500
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 77)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 486
# 0 rows are removed
# 0 rows are removed
# number of used genes = 486
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
#%% plot
# Plotting functions
dec_min = 0
dec_max = 0
drugs = sorted(list(set([t.split("_")[0] for t in ensemble_df.index.tolist()])))
colorlist = ["tab:blue", "tab:orange", "tab:green", "tab:red", "tab:purple", "tab:brown", "tab:pink", "tab:gray"]
colordic = dict(zip(drugs,colorlist))

handles = []
fig,ax = plt.subplots(figsize=(5,5))
for i,d in enumerate(drugs):
    res1 = ensemble_df.filter(regex="^"+d+"_",axis=0).T
    res2 = x_df.filter(regex="^"+d+"_",axis=0).T
    std_df = res1.std().T
    
    #tmp_cor = round(np.corrcoef(res1,res2)[0][1],3)
    for n,j in enumerate(res1.columns.tolist()):
        plt.errorbar(x=res1[j].mean(),y=res2[j].tolist(),xerr=std_df[j],capsize=10,marker='_',fmt='o',ms=8,mew=1,color=colordic.get(d),zorder=-1)
        sc = plt.scatter(res1[j],[res2[j]]*len(res1),label=d,alpha=0.95,color=colordic.get(d),s=60,linewidths=0.4,edgecolor='k')
        if n == 0:
            handles.append(sc)
    
    if res1.min().min()<dec_min:
        dec_min = res1.min().min()
    if res1.max().max()>dec_max:
        dec_max = res1.max().max()
plt.plot([dec_min,dec_max],[dec_min,dec_max],linewidth=2,color='black',linestyle='dashed',zorder=-1)
plt.legend(handles,drugs,shadow=True,loc='upper left', borderaxespad=0, bbox_to_anchor=(1, 1))
plt.xlabel("Deconvolution estimated value",fontsize=18)
plt.ylabel("FACS value",fontsize=18)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
ax.set_axisbelow(True)
ax.grid(color="#ababab",linewidth=0.5)
plt.title("Good combinations for NK cells",fontsize=18)
plt.show()

# %% [markdown]
# ***
# ##### Summary of bad combinations

# %%
#%% Bad
# bottom 10 good combinations
nk_res = pd.read_pickle(Base_dir+'/_Figures_new/Figure_4/data/nk_fluctuate_quartile_comb2ref.pkl')
nk_res = nk_res.sort_values('NK',ascending=True)
print(nk_res.head())
bad_combination = nk_res['pair'].tolist()[0:10]

# load data
mix_df = pd.read_csv(Base_dir + '/data/mix_processed.csv',index_col=0)
raw_ref = pd.read_csv(Base_dir + '/data/ref_13types.csv',index_col=0)
val_df = pd.read_csv(Base_dir + '/data/facs_true_population.csv',index_col=0)

# each result of good combinations
ensemble = []
for b in bad_combination:
    optim = cnco.Ctrlnorm_comb2ref()
    optim.set_datasets(mix_df=mix_df,val_df=val_df,ignore_samples=['CIV_1','CIV_4','CIV_7','CIV_8','CIP_1','CIP_2','CIP_7','CIP_8'])
    optim.set_target(target="NK")
    optim.select_samples(method="outerquartile",ctrl="Ctrl",threshold=1.5,q=[0, 0.25, 0.5, 0.75, 1],ignore_ctrl=True)
    optim.optimized_single(raw_ref=raw_ref,combination=b,target=["NK"],dec_names=[["NK"]],val_names=[["NK"]],do_plot=True,dpi=100)
    res = optim.final_dec
    val = optim.final_val
    ensemble.append(res["NK"].tolist())

# ensemble the estimated values for each iterations
ensemble_df = pd.DataFrame(ensemble).T
ensemble_df.index = res.index.tolist()
x = optim.final_val["NK"].tolist()
pd.Series(ensemble[0]).corr(pd.Series(x))
x_df = pd.DataFrame(x)
x_df.index = res.index.tolist()
# Out:
#                                      NK                             pair
# (CD4, CD8, Hepatocyte, Kupffer) -0.1581  (CD4, CD8, Hepatocyte, Kupffer)
# (B, Cholangiocyte, Hepatocyte)  -0.1407   (B, Cholangiocyte, Hepatocyte)
# (CD4, CD8, Kupffer)             -0.0236              (CD4, CD8, Kupffer)
# (B, CD4, CD8, Kupffer)          -0.0234           (B, CD4, CD8, Kupffer)
# (Cholangiocyte, Hepatocyte)     -0.0212      (Cholangiocyte, Hepatocyte)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 57)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 250
# 0 rows are removed
# 0 rows are removed
# number of used genes = 250
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 32)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 200
# 0 rows are removed
# 0 rows are removed
# number of used genes = 200
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 47)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 200
# 0 rows are removed
# 0 rows are removed
# number of used genes = 200
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 58)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 250
# 0 rows are removed
# 0 rows are removed
# number of used genes = 250
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 21)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 150
# 0 rows are removed
# 0 rows are removed
# number of used genes = 150
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 41)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 200
# 0 rows are removed
# 0 rows are removed
# number of used genes = 200
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 32)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 150
# 0 rows are removed
# 0 rows are removed
# number of used genes = 150
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 31)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 200
# 0 rows are removed
# 0 rows are removed
# number of used genes = 200
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 37)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 250
# 0 rows are removed
# 0 rows are removed
# number of used genes = 250
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  NK
# --- evaluation ---
# target:  NK
# 20 / 40 samples are analytical target
# (11588, 53)
# (51463, 27)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 200
# 0 rows are removed
# 0 rows are removed
# number of used genes = 200
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
#%% plot
# Plotting functions
dec_min = 0
dec_max = 0
drugs = sorted(list(set([t.split("_")[0] for t in ensemble_df.index.tolist()])))
colorlist = ["tab:blue", "tab:orange", "tab:green", "tab:red", "tab:purple", "tab:brown", "tab:pink", "tab:gray"]
colordic = dict(zip(drugs,colorlist))

handles = []
fig,ax = plt.subplots(figsize=(5,5))
for i,d in enumerate(drugs):
    res1 = ensemble_df.filter(regex="^"+d+"_",axis=0).T
    res2 = x_df.filter(regex="^"+d+"_",axis=0).T
    std_df = res1.std().T
    
    #tmp_cor = round(np.corrcoef(res1,res2)[0][1],3)
    for n,j in enumerate(res1.columns.tolist()):
        plt.errorbar(x=res1[j].mean(),y=res2[j].tolist(),xerr=std_df[j],capsize=10,marker='_',fmt='o',ms=8,mew=1,color=colordic.get(d),zorder=-1)
        sc = plt.scatter(res1[j],[res2[j]]*len(res1),label=d,alpha=0.95,color=colordic.get(d),s=60,linewidths=0.4,edgecolor='k')
        if n == 0:
            handles.append(sc)
    
    if res1.min().min()<dec_min:
        dec_min = res1.min().min()
    if res1.max().max()>dec_max:
        dec_max = res1.max().max()
plt.plot([dec_min,dec_max],[dec_min,dec_max],linewidth=2,color='black',linestyle='dashed',zorder=-1)
plt.legend(handles,drugs,shadow=True,loc='upper left', borderaxespad=0, bbox_to_anchor=(1, 1))
plt.xlabel("Deconvolution estimated value",fontsize=18)
plt.ylabel("FACS value",fontsize=18)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
ax.set_axisbelow(True)
ax.grid(color="#ababab",linewidth=0.5)
plt.title("Bad combinations for NK cells",fontsize=18)
plt.show()
