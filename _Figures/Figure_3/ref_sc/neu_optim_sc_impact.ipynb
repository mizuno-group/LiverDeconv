# %% [markdown]
# ##### Optimization impact on Neutrophil estimation
# - single-cell derived LM10 reference

# %%
Base_dir = 'C:/github/LiverDeconv' # cloning repository

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append(Base_dir)
from Optimization import ctrl_norm_comb2ref_optim as cnco

CELL = 'Neutrophil'

# %% [markdown]
# ***
# ##### Total combination for estimating Neutrophils population
# - Disribution of Pearson Correlation for 511 all combinations

# %%
#%% load data
neu_res = pd.read_csv(Base_dir+'/_Figures/Figure_3/data/sc/neu_fluctuate_quartile_comb2ref_sc.csv',index_col=0)
neu_res = neu_res.sort_values(CELL,ascending=False)

plt.hist(neu_res[CELL],bins=100,zorder=1)
plt.xlabel('Pearson Correlation')
plt.ylabel('Frequency')
plt.rcParams['axes.axisbelow'] = True
plt.grid(color="#ababab",linewidth=0.5)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
plt.title(CELL)
plt.show()

# %%
for target in ['LSEC', 'NK', 'CD8', 'B', 'Kupffer', 'Hepatocyte', 'Cholangiocyte', 'Stellate', 'Monocyte']:
    sns.distplot(
        neu_res[CELL], bins=200, label='all combinations',color='slateblue',kde_kws={"lw": 2},hist_kws={"alpha": 0.6})
    df = neu_res[neu_res['pair'].str.contains("'"+target+"'")]
    
    sns.distplot(
        df[CELL], bins=100, color='forestgreen', label="contains "+target, kde_kws={"lw": 2},hist_kws={"alpha": 0.6}
    )
    
    plt.xlabel('Pearson Correlation')
    plt.ylabel('Frequency')
    plt.rcParams['axes.axisbelow'] = True
    plt.grid(color="#ababab",linewidth=0.5,zorder=-1)
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().yaxis.set_ticks_position('left')
    plt.gca().xaxis.set_ticks_position('bottom')
    plt.title("Combination contains "+target)
    plt.legend()
    plt.show()

# %% [markdown]
# ***
# ##### Summary of good combinations

# %%
#%% Good
# top 10 good combinations
comb_res = pd.read_pickle(Base_dir+'/_Figures/Figure_3/data/sc/neu_fluctuate_quartile_comb2ref_sc.pkl')
comb_res = comb_res.sort_values(CELL,ascending=False)
print(comb_res.head())
good_combination = comb_res['pair'].tolist()[0:10]

# load data
mix_df = pd.read_csv(Base_dir + '/data/processed/mix_processed.csv',index_col=0)
val_df = pd.read_csv(Base_dir + '/data/processed/facs_true_population.csv',index_col=0)
raw_ref = pd.read_csv('d:/datasource/Deconvolution/E-MTAB-8263/processed/lm10_mean_27998x332.csv',index_col=0)
ann_df = pd.read_csv('c:/github/LiverDeconv/Data/raw/Mouse_stable2MouseMGI.csv')

# each result of good combinations
ensemble = []
for g in good_combination:
    optim = cnco.Ctrlnorm_comb2ref()
    optim.set_datasets(mix_df=mix_df,val_df=val_df,ignore_samples=['CIV_1','CIV_4','CIV_7','CIV_8','CIP_1','CIP_2','CIP_7','CIP_8'])
    optim.set_target(target=CELL)
    optim.select_samples(method="outerquartile",ctrl="Ctrl",threshold=1.5,q=[0, 0.25, 0.5, 0.75, 1],ignore_ctrl=True)
    optim.optimized_single(raw_ref=raw_ref,ann_df=ann_df,combination=g,target=[CELL],dec_names=[[CELL]],val_names=[[CELL]],do_plot=True,dpi=100)
    res = optim.final_dec
    val = optim.final_val
    ensemble.append(res[CELL].tolist())

# ensemble the estimated values for each iterations
ensemble_df = pd.DataFrame(ensemble).T
ensemble_df.index = res.index.tolist()
x = optim.final_val[CELL].tolist()
pd.Series(ensemble[0]).corr(pd.Series(x))
x_df = pd.DataFrame(x)
x_df.index = res.index.tolist()

#%% plot
# Plotting functions
dec_min = 0
dec_max = 0
drugs = sorted(list(set([t.split("_")[0] for t in ensemble_df.index.tolist()])))
colorlist = ["tab:blue", "tab:orange", "tab:green", "tab:red", "tab:purple", "tab:brown", "tab:pink", "tab:gray"]
colordic = dict(zip(drugs,colorlist))

handles = []
fig,ax = plt.subplots(figsize=(5,5))
for i,d in enumerate(drugs):
    res1 = ensemble_df.filter(regex="^"+d+"_",axis=0).T
    res2 = x_df.filter(regex="^"+d+"_",axis=0).T
    std_df = res1.std().T
    
    #tmp_cor = round(np.corrcoef(res1,res2)[0][1],3)
    for n,j in enumerate(res1.columns.tolist()):
        plt.errorbar(x=res1[j].mean(),y=res2[j].tolist(),xerr=std_df[j],capsize=10,marker='_',fmt='o',ms=8,mew=1,color=colordic.get(d),zorder=-1)
        sc = plt.scatter(res1[j],[res2[j]]*len(res1),label=d,alpha=0.95,color=colordic.get(d),s=60,linewidths=0.4,edgecolor='k')
        if n == 0:
            handles.append(sc)
    
    if res1.min().min()<dec_min:
        dec_min = res1.min().min()
    if res1.max().max()>dec_max:
        dec_max = res1.max().max()
plt.plot([dec_min,dec_max],[dec_min,dec_max],linewidth=2,color='black',linestyle='dashed',zorder=-1)
plt.legend(handles,drugs,shadow=True,loc='upper left', borderaxespad=0, bbox_to_anchor=(1, 1))
plt.xlabel("Deconvolution estimated value",fontsize=18)
plt.ylabel("FACS value",fontsize=18)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
ax.set_axisbelow(True)
ax.grid(color="#ababab",linewidth=0.5)
plt.title(f"Good combinations for {CELL}",fontsize=18)
plt.show()
# Out:
#                                        Neutrophil  \
# (B, Monocyte, Stellate)                    0.8004
# (CD8, Monocyte, Stellate)                  0.7846
# (B, Kupffer, Monocyte, NK, Stellate)       0.7712
# (Monocyte, Stellate)                       0.7703
# (B, CD8, Kupffer, Monocyte, Stellate)      0.7692
#
#                                                                         pair
# (B, Monocyte, Stellate)                              (B, Monocyte, Stellate)
# (CD8, Monocyte, Stellate)                          (CD8, Monocyte, Stellate)
# (B, Kupffer, Monocyte, NK, Stellate)    (B, Kupffer, Monocyte, NK, Stellate)
# (Monocyte, Stellate)                                    (Monocyte, Stellate)
# (B, CD8, Kupffer, Monocyte, Stellate)  (B, CD8, Kupffer, Monocyte, Stellate)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 4)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 112
# 0 rows are removed
# 0 rows are removed
# number of used genes = 112
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 4)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 110
# 0 rows are removed
# 0 rows are removed
# number of used genes = 110
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 6)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 125
# 0 rows are removed
# 0 rows are removed
# number of used genes = 125
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 3)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 96
# 0 rows are removed
# 0 rows are removed
# number of used genes = 96
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 6)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 127
# 0 rows are removed
# 0 rows are removed
# number of used genes = 127
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 6)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 130
# 0 rows are removed
# 0 rows are removed
# number of used genes = 130
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 6)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 119
# 0 rows are removed
# 0 rows are removed
# number of used genes = 119
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 7)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 128
# 0 rows are removed
# 0 rows are removed
# number of used genes = 128
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 6)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 132
# 0 rows are removed
# 0 rows are removed
# number of used genes = 132
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 5)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 119
# 0 rows are removed
# 0 rows are removed
# number of used genes = 119
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %% [markdown]
# ***
# ##### Summary of bad combinations

# %%
#%% Good
# top 10 good combinations
comb_res = pd.read_pickle(Base_dir+'/_Figures/Figure_3/data/sc/neu_fluctuate_quartile_comb2ref_sc.pkl')
comb_res = comb_res.sort_values(CELL,ascending=True)
print(comb_res.head())
bad_combination = comb_res['pair'].tolist()[0:10]

# load data
mix_df = pd.read_csv(Base_dir + '/data/processed/mix_processed.csv',index_col=0)
val_df = pd.read_csv(Base_dir + '/data/processed/facs_true_population.csv',index_col=0)
raw_ref = pd.read_csv('d:/datasource/Deconvolution/E-MTAB-8263/processed/lm10_mean_27998x332.csv',index_col=0)
ann_df = pd.read_csv('c:/github/LiverDeconv/Data/raw/Mouse_stable2MouseMGI.csv')

# each result of good combinations
ensemble = []
for b in bad_combination:
    optim = cnco.Ctrlnorm_comb2ref()
    optim.set_datasets(mix_df=mix_df,val_df=val_df,ignore_samples=['CIV_1','CIV_4','CIV_7','CIV_8','CIP_1','CIP_2','CIP_7','CIP_8'])
    optim.set_target(target=CELL)
    optim.select_samples(method="outerquartile",ctrl="Ctrl",threshold=1.5,q=[0, 0.25, 0.5, 0.75, 1],ignore_ctrl=True)
    optim.optimized_single(raw_ref=raw_ref,ann_df=ann_df,combination=b,target=[CELL],dec_names=[[CELL]],val_names=[[CELL]],do_plot=True,dpi=100)
    res = optim.final_dec
    val = optim.final_val
    ensemble.append(res[CELL].tolist())

# ensemble the estimated values for each iterations
ensemble_df = pd.DataFrame(ensemble).T
ensemble_df.index = res.index.tolist()
x = optim.final_val[CELL].tolist()
pd.Series(ensemble[0]).corr(pd.Series(x))
x_df = pd.DataFrame(x)
x_df.index = res.index.tolist()

#%% plot
# Plotting functions
dec_min = 0
dec_max = 0
drugs = sorted(list(set([t.split("_")[0] for t in ensemble_df.index.tolist()])))
colorlist = ["tab:blue", "tab:orange", "tab:green", "tab:red", "tab:purple", "tab:brown", "tab:pink", "tab:gray"]
colordic = dict(zip(drugs,colorlist))

handles = []
fig,ax = plt.subplots(figsize=(5,5))
for i,d in enumerate(drugs):
    res1 = ensemble_df.filter(regex="^"+d+"_",axis=0).T
    res2 = x_df.filter(regex="^"+d+"_",axis=0).T
    std_df = res1.std().T
    
    #tmp_cor = round(np.corrcoef(res1,res2)[0][1],3)
    for n,j in enumerate(res1.columns.tolist()):
        plt.errorbar(x=res1[j].mean(),y=res2[j].tolist(),xerr=std_df[j],capsize=10,marker='_',fmt='o',ms=8,mew=1,color=colordic.get(d),zorder=-1)
        sc = plt.scatter(res1[j],[res2[j]]*len(res1),label=d,alpha=0.95,color=colordic.get(d),s=60,linewidths=0.4,edgecolor='k')
        if n == 0:
            handles.append(sc)
    
    if res1.min().min()<dec_min:
        dec_min = res1.min().min()
    if res1.max().max()>dec_max:
        dec_max = res1.max().max()
plt.plot([dec_min,dec_max],[dec_min,dec_max],linewidth=2,color='black',linestyle='dashed',zorder=-1)
plt.legend(handles,drugs,shadow=True,loc='upper left', borderaxespad=0, bbox_to_anchor=(1, 1))
plt.xlabel("Deconvolution estimated value",fontsize=18)
plt.ylabel("FACS value",fontsize=18)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
ax.set_axisbelow(True)
ax.grid(color="#ababab",linewidth=0.5)
plt.title(f"Bad combinations for {CELL}",fontsize=18)
plt.show()
# Out:
#                                        Neutrophil  \
# (Hepatocyte,)                             -0.1463
# (Cholangiocyte, Hepatocyte)               -0.0601
# (CD8, Hepatocyte)                          0.0901
# (CD8, Cholangiocyte, Hepatocyte)           0.1070
# (Cholangiocyte, Hepatocyte, Stellate)      0.1102
#
#                                                                         pair
# (Hepatocyte,)                                                  (Hepatocyte,)
# (Cholangiocyte, Hepatocyte)                      (Cholangiocyte, Hepatocyte)
# (CD8, Hepatocyte)                                          (CD8, Hepatocyte)
# (CD8, Cholangiocyte, Hepatocyte)            (CD8, Cholangiocyte, Hepatocyte)
# (Cholangiocyte, Hepatocyte, Stellate)  (Cholangiocyte, Hepatocyte, Stellate)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 2)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 91
# 0 rows are removed
# 0 rows are removed
# number of used genes = 91
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 3)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 121
# 0 rows are removed
# 0 rows are removed
# number of used genes = 121
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 3)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 125
# 0 rows are removed
# 0 rows are removed
# number of used genes = 125
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 4)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 138
# 0 rows are removed
# 0 rows are removed
# number of used genes = 138
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 4)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 135
# 0 rows are removed
# 0 rows are removed
# number of used genes = 135
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 4)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 138
# 0 rows are removed
# 0 rows are removed
# number of used genes = 138
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 5)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 142
# 0 rows are removed
# 0 rows are removed
# number of used genes = 142
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 3)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 121
# 0 rows are removed
# 0 rows are removed
# number of used genes = 121
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 4)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 131
# 0 rows are removed
# 0 rows are removed
# number of used genes = 131
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# target:  Neutrophil
# --- evaluation ---
# target:  Neutrophil
# 18 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (27998, 3)
# log2 conversion
# quantile normalization
# narrowd gene number : 11181
# signature genes : 127
# 0 rows are removed
# 0 rows are removed
# number of used genes = 127
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\Users\Mizu2020\piphazuma\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
