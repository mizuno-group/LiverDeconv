# %% [markdown]
# #### Optimized impact on Eosinophil estimation

# %%
Base_dir = 'C:/github/LiverDeconv' # cloning repository

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append(Base_dir)
from Optimization import ctrl_norm_comb2ref_optim as cnco

# %% [markdown]
# ***
# ##### Total combination for estimating neutrophil population
# - Distribution of Pearson Correlation for 4095 combinations

# %%
#%% load data
mon_res = pd.read_csv(Base_dir+'/_Figures_new/Figure_4/data/mon_fluctuate_quartile_comb2ref.csv',index_col=0)
mon_res = mon_res.sort_values('Monocyte',ascending=False)

plt.hist(mon_res['Monocyte'],bins=200,zorder=1)
plt.xlabel('Pearson Correlation')
plt.ylabel('Frequency')
plt.rcParams['axes.axisbelow'] = True
plt.grid(color="#ababab",linewidth=0.5)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
plt.title("Monocyte")
plt.show()

# %%
for target in ['LSEC', 'Basophil', 'CD4', 'NK', 'CD8', 'Eosinophil', 'B', 
               'Kupffer', 'Hepatocyte', 'Cholangiocyte', 'Stellate', 'Neutrophil']:
    sns.distplot(
        mon_res['Monocyte'], bins=200, label='all combinations',color='slateblue',kde_kws={"lw": 2},hist_kws={"alpha": 0.6})
    df = mon_res[mon_res['pair'].str.contains("'"+target+"'")]
    
    sns.distplot(
        df['Monocyte'], bins=100, color='forestgreen', label="contains "+target, kde_kws={"lw": 2},hist_kws={"alpha": 0.6}
    )
    
    plt.xlabel('Pearson Correlation')
    plt.ylabel('Frequency')
    plt.rcParams['axes.axisbelow'] = True
    plt.grid(color="#ababab",linewidth=0.5,zorder=-1)
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().yaxis.set_ticks_position('left')
    plt.gca().xaxis.set_ticks_position('bottom')
    plt.title("Combination contains "+target)
    plt.legend()
    plt.show()

# %% [markdown]
# ***
# #### Good combination summary

# %%
#%% Good
# top 10 good combinations
mon_res = pd.read_pickle(Base_dir+'/_Figures_new/Figure_4/data/mon_fluctuate_quartile_comb2ref.pkl')
mon_res = mon_res.sort_values('Monocyte',ascending=False)
print(mon_res.head())
good_combination = mon_res['pair'].tolist()[0:10]

# load data
mix_df = pd.read_csv(Base_dir + '/data/processed/mix_processed.csv',index_col=0)
raw_ref = pd.read_csv(Base_dir + '/data/processed/ref_13types.csv',index_col=0)
val_df = pd.read_csv(Base_dir + '/data/processed/facs_true_population.csv',index_col=0)

# each result of good combinations
ensemble = []
for g in good_combination:
    optim = cnco.Ctrlnorm_comb2ref()
    optim.set_datasets(mix_df=mix_df,val_df=val_df,ignore_samples=['CIV_1','CIV_4','CIV_7','CIV_8','CIP_1','CIP_2','CIP_7','CIP_8'])
    optim.set_target(target="Monocyte")
    optim.select_samples(method="outerquartile",ctrl="Ctrl",threshold=1.5,q=[0, 0.25, 0.5, 0.75, 1],ignore_ctrl=True)
    optim.optimized_single(raw_ref=raw_ref,combination=g,target=["Monocyte"],dec_names=[["Monocyte"]],val_names=[["Monocyte"]],do_plot=True,dpi=100)
    res = optim.final_dec
    val = optim.final_val
    ensemble.append(res["Monocyte"].tolist())

# ensemble the estimated values for each iterations
ensemble_df = pd.DataFrame(ensemble).T
ensemble_df.index = res.index.tolist()
x = optim.final_val["Monocyte"].tolist()
pd.Series(ensemble[0]).corr(pd.Series(x))
x_df = pd.DataFrame(x)
x_df.index = res.index.tolist()
# Out:
#                     Monocyte                pair
# (B, CD4, NK)          0.8563        (B, CD4, NK)
# (B, CD4, LSEC, NK)    0.8328  (B, CD4, LSEC, NK)
# (CD4, CD8, LSEC)      0.8324    (CD4, CD8, LSEC)
# (CD4, NK)             0.8302           (CD4, NK)
# (CD8, LSEC, NK)       0.8289     (CD8, LSEC, NK)
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 38)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 200
# 0 rows are removed
# 0 rows are removed
# number of used genes = 200
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 48)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 250
# 0 rows are removed
# 0 rows are removed
# number of used genes = 250
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 43)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 200
# 0 rows are removed
# 0 rows are removed
# number of used genes = 200
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 27)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 150
# 0 rows are removed
# 0 rows are removed
# number of used genes = 150
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 38)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 200
# 0 rows are removed
# 0 rows are removed
# number of used genes = 200
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 31)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 150
# 0 rows are removed
# 0 rows are removed
# number of used genes = 150
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 31)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 200
# 0 rows are removed
# 0 rows are removed
# number of used genes = 200
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 39)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 200
# 0 rows are removed
# 0 rows are removed
# number of used genes = 200
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 41)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 250
# 0 rows are removed
# 0 rows are removed
# number of used genes = 250
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 44)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 200
# 0 rows are removed
# 0 rows are removed
# number of used genes = 200
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------

# %%
#%% plot
# Plotting functions
dec_min = 0
dec_max = 0
drugs = sorted(list(set([t.split("_")[0] for t in ensemble_df.index.tolist()])))
colorlist = ["tab:blue", "tab:orange", "tab:green", "tab:red", "tab:purple", "tab:brown", "tab:pink", "tab:gray"]
colordic = dict(zip(drugs,colorlist))

handles = []
fig,ax = plt.subplots(figsize=(5,5))
for i,d in enumerate(drugs):
    res1 = ensemble_df.filter(regex="^"+d+"_",axis=0).T
    res2 = x_df.filter(regex="^"+d+"_",axis=0).T
    std_df = res1.std().T
    
    #tmp_cor = round(np.corrcoef(res1,res2)[0][1],3)
    for n,j in enumerate(res1.columns.tolist()):
        plt.errorbar(x=res1[j].mean(),y=res2[j].tolist(),xerr=std_df[j],capsize=10,marker='_',fmt='o',ms=8,mew=1,color=colordic.get(d),zorder=-1)
        sc = plt.scatter(res1[j],[res2[j]]*len(res1),label=d,alpha=0.95,color=colordic.get(d),s=60,linewidths=0.4,edgecolor='k')
        if n == 0:
            handles.append(sc)
    
    if res1.min().min()<dec_min:
        dec_min = res1.min().min()
    if res1.max().max()>dec_max:
        dec_max = res1.max().max()
plt.plot([dec_min,dec_max],[dec_min,dec_max],linewidth=2,color='black',linestyle='dashed',zorder=-1)
plt.legend(handles,drugs,shadow=True,loc='upper left', borderaxespad=0, bbox_to_anchor=(1, 1))
plt.xlabel("Deconvolution estimated value",fontsize=18)
plt.ylabel("FACS value",fontsize=18)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
ax.set_axisbelow(True)
ax.grid(color="#ababab",linewidth=0.5)
plt.title("Good combinations for Monocytes",fontsize=18)
plt.show()

# %% [markdown]
# ***
# #### Bad combination summary

# %%
#%% Bad
# bottom 10 good combinations
mon_res = pd.read_pickle(Base_dir+'/_Figures_new/Figure_4/data/mon_fluctuate_quartile_comb2ref.pkl')
mon_res = mon_res.sort_values('Monocyte',ascending=True)
print(mon_res.head())
good_combination = mon_res['pair'].tolist()[0:10]

# load data
mix_df = pd.read_csv(Base_dir + '/data/processed/mix_processed.csv',index_col=0)
raw_ref = pd.read_csv(Base_dir + '/data/processed/ref_13types.csv',index_col=0)
val_df = pd.read_csv(Base_dir + '/data/processed/facs_true_population.csv',index_col=0)

# each result of good combinations
ensemble = []
for g in good_combination:
    optim = cnco.Ctrlnorm_comb2ref()
    optim.set_datasets(mix_df=mix_df,val_df=val_df,ignore_samples=['CIV_1','CIV_4','CIV_7','CIV_8','CIP_1','CIP_2','CIP_7','CIP_8'])
    optim.set_target(target="Monocyte")
    optim.select_samples(method="outerquartile",ctrl="Ctrl",threshold=1.5,q=[0, 0.25, 0.5, 0.75, 1],ignore_ctrl=True)
    optim.optimized_single(raw_ref=raw_ref,combination=g,target=["Monocyte"],dec_names=[["Monocyte"]],val_names=[["Monocyte"]],do_plot=True,dpi=100)
    res = optim.final_dec
    val = optim.final_val
    ensemble.append(res["Monocyte"].tolist())

# ensemble the estimated values for each iterations
ensemble_df = pd.DataFrame(ensemble).T
ensemble_df.index = res.index.tolist()
x = optim.final_val["Monocyte"].tolist()
pd.Series(ensemble[0]).corr(pd.Series(x))
x_df = pd.DataFrame(x)
x_df.index = res.index.tolist()
# Out:
#                                          Monocyte  \
# (CD8, Hepatocyte, Kupffer)                -0.3265
# (Kupffer, Stellate)                       -0.3104
# (CD8, Cholangiocyte, Kupffer, Stellate)   -0.2284
# (CD8, Hepatocyte, Kupffer, Stellate)      -0.2281
# (B, Cholangiocyte, Kupffer, Stellate)     -0.2269
#
#                                                                             pair
# (CD8, Hepatocyte, Kupffer)                            (CD8, Hepatocyte, Kupffer)
# (Kupffer, Stellate)                                          (Kupffer, Stellate)
# (CD8, Cholangiocyte, Kupffer, Stellate)  (CD8, Cholangiocyte, Kupffer, Stellate)
# (CD8, Hepatocyte, Kupffer, Stellate)        (CD8, Hepatocyte, Kupffer, Stellate)
# (B, Cholangiocyte, Kupffer, Stellate)      (B, Cholangiocyte, Kupffer, Stellate)
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 42)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 200
# 0 rows are removed
# 0 rows are removed
# number of used genes = 200
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 24)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 150
# 0 rows are removed
# 0 rows are removed
# number of used genes = 150
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 41)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 250
# 0 rows are removed
# 0 rows are removed
# number of used genes = 250
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 48)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 250
# 0 rows are removed
# 0 rows are removed
# number of used genes = 250
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 38)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 250
# 0 rows are removed
# 0 rows are removed
# number of used genes = 250
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 58)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 400
# 0 rows are removed
# 0 rows are removed
# number of used genes = 400
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 48)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 250
# 0 rows are removed
# 0 rows are removed
# number of used genes = 250
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 48)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 300
# 0 rows are removed
# 0 rows are removed
# number of used genes = 300
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 45)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 300
# 0 rows are removed
# 0 rows are removed
# number of used genes = 300
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------
# target:  Monocyte
# --- evaluation ---
# target:  Monocyte
# 19 / 40 samples are analytical target
# !! Attention! Sample size may be too small. !!
# (11588, 53)
# (51463, 38)
# log2 conversion
# quantile normalization
# narrowd gene number : 11555
# signature genes : 250
# 0 rows are removed
# 0 rows are removed
# number of used genes = 250
# fitting method : ElasticNet
# standardz population control
# standardz population control
# ----------

# %%
#%% plot
# Plotting functions
dec_min = 0
dec_max = 0
drugs = sorted(list(set([t.split("_")[0] for t in ensemble_df.index.tolist()])))
colorlist = ["tab:blue", "tab:orange", "tab:green", "tab:red", "tab:purple", "tab:brown", "tab:pink", "tab:gray"]
colordic = dict(zip(drugs,colorlist))

handles = []
fig,ax = plt.subplots(figsize=(5,5))
for i,d in enumerate(drugs):
    res1 = ensemble_df.filter(regex="^"+d+"_",axis=0).T
    res2 = x_df.filter(regex="^"+d+"_",axis=0).T
    std_df = res1.std().T
    
    #tmp_cor = round(np.corrcoef(res1,res2)[0][1],3)
    for n,j in enumerate(res1.columns.tolist()):
        plt.errorbar(x=res1[j].mean(),y=res2[j].tolist(),xerr=std_df[j],capsize=10,marker='_',fmt='o',ms=8,mew=1,color=colordic.get(d),zorder=-1)
        sc = plt.scatter(res1[j],[res2[j]]*len(res1),label=d,alpha=0.95,color=colordic.get(d),s=60,linewidths=0.4,edgecolor='k')
        if n == 0:
            handles.append(sc)
    
    if res1.min().min()<dec_min:
        dec_min = res1.min().min()
    if res1.max().max()>dec_max:
        dec_max = res1.max().max()
plt.plot([dec_min,dec_max],[dec_min,dec_max],linewidth=2,color='black',linestyle='dashed',zorder=-1)
plt.legend(handles,drugs,shadow=True,loc='upper left', borderaxespad=0, bbox_to_anchor=(1, 1))
plt.xlabel("Deconvolution estimated value",fontsize=18)
plt.ylabel("FACS value",fontsize=18)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
ax.set_axisbelow(True)
ax.grid(color="#ababab",linewidth=0.5)
plt.title("Bad combinations for Monocytes",fontsize=18)
plt.show()
